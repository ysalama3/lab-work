# %% [markdown]
# ## In lab questions

# %% [markdown]
# 1-How many fossils are included in the dataset? 2946

# %% [markdown]
# 2-How many fossils have been identified to genus-level only? 2106
# How many to species level? 607

# %%
import csv
with open("/home/eeb177-student/Desktop/eeb-177/lab-work/exercise-9/canid_occ.csv", newline='') as infh:
    reader = csv.reader(infh)
    counter = 0
    for row in reader:
        
    
        if row[6] == "species":
            print(str(counter) + " " + row[5])
            counter += 1
# Out:
# 0 Cynodictis lacustris
# 1 Neovulpavus washakius
# 2 Hesperocyon gregarius
# 3 Hesperocyon gregarius
# 4 Hesperocyon gregarius
# 5 Hesperocyon gregarius
# 6 Hesperocyon gregarius
# 7 Hesperocyon gregarius
# 8 Hesperocyon gregarius
# 9 Hesperocyon gregarius
# 10 Hesperocyon gregarius
# 11 Hesperocyon gregarius
# 12 Hesperocyon gregarius
# 13 Hesperocyon gregarius
# 14 Hesperocyon gregarius
# 15 Hesperocyon gregarius
# 16 Hesperocyon gregarius
# 17 Hesperocyon gregarius
# 18 Hesperocyon gregarius
# 19 Hesperocyon gregarius
# 20 Hesperocyon gregarius
# 21 Hesperocyon gregarius
# 22 Hesperocyon gregarius
# 23 Hesperocyon gregarius
# 24 Hesperocyon gregarius
# 25 Hesperocyon gregarius
# 26 Hesperocyon gregarius
# 27 Hesperocyon gregarius
# 28 Hesperocyon gregarius
# 29 Hesperocyon gregarius
# 30 Hesperocyon gregarius
# 31 Hesperocyon gregarius
# 32 Hesperocyon gregarius
# 33 Hesperocyon gregarius
# 34 Hesperocyon gregarius
# 35 Hesperocyon gregarius
# 36 Hesperocyon gregarius
# ...

# %%
import csv
with open("/home/eeb177-student/Desktop/eeb-177/lab-work/exercise-9/canid_occ.csv", newline='') as infh:
    reader = csv.reader(infh)
    counter = 0
    for row in reader:
        
    
        if row[6] == "genus":
            print(str(counter) + " " + row[5])
            counter += 1
# Out:
# 0 Cuon
# 1 Hesperocyon
# 2 Hesperocyon
# 3 Hesperocyon
# 4 Hesperocyon
# 5 Hesperocyon
# 6 Hesperocyon
# 7 Hesperocyon
# 8 Hesperocyon
# 9 Hesperocyon
# 10 Hesperocyon
# 11 Hesperocyon
# 12 Hesperocyon
# 13 Hesperocyon
# 14 Hesperocyon
# 15 Hesperocyon
# 16 Hesperocyon
# 17 Hesperocyon
# 18 Hesperocyon
# 19 Hesperocyon
# 20 Hesperocyon
# 21 Hesperocyon
# 22 Hesperocyon
# 23 Hesperocyon
# 24 Hesperocyon
# 25 Hesperocyon
# 26 Hesperocyon
# 27 Hesperocyon
# 28 Hesperocyon
# 29 Hesperocyon
# 30 Hesperocyon
# 31 Oxetocyon
# 32 Hesperocyon
# 33 Oxetocyon
# 34 Enhydrocyon
# 35 Hesperocyon
# 36 Hesperocyon
# 37 Hesperocyon
# 38 Enhydrocyon
# 39 Enhydrocyon
# 40 Cormocyon
# 41 Enhydrocyon
# 42 Phlaocyon
# 43 Phlaocyon
# 44 Leptocyon
# 45 Leptocyon
# 46 Aelurodon
# 47 Borophagus
# 48 Epicyon
# 49 Borophagus
# 50 Borophagus
# 51 Borophagus
# 52 Cynarctus
# 53 Borophagus
# 54 Aelurodon
# 55 Leptocyon
# 56 Borophagus
# 57 Aelurodon
# 58 Epicyon
# 59 Borophagus
# 60 Aelurodon
# 61 Leptocyon
# ...

# %% [markdown]
# 3-How many unique accepted names are part of this dataset? 211

# %% [markdown]
# ```
# tail -n+2 canid_occ.csv | cut -d "," -f 6 | sort | uniq | wc -l
# ```

# %% [markdown]
# 1-How can we change the sampling frequency of our PyRate run? use -n 250000 for 250000 steps in the MCMC chain
# 2-What does the -n flag achieve? specifying number of steps
